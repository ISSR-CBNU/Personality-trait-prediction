# %%
import librosa
import librosa.display
import numpy as np
import pandas as pd
import os
from typing import List, Tuple, Dict
import matplotlib.pyplot as plt
import random
import cv2
# from vgg16 import VGG16_LSTM
import pickle
import torch.nn as nn
import torch
import datetime
import torch.nn.functional as F
import torchvision.models as models
from torchvision import transforms, utils, models
from torch.utils.data import Dataset, DataLoader
from facenet_pytorch import MTCNN
import logging
import torch
import torch.nn as nn
from vivit import ViViTBackbone
import gc
from einops import rearrange
from tqdm import tqdm
batchsz = 4
frame_nums=15
start_epoch = 0
test_flage=False
model_name ="15framesfullshot"
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('[%(asctime)s]::%(module)s::%(levelname)s::%(message)s')
streamHandler = logging.StreamHandler()
streamHandler.setFormatter(formatter)
fileHandler = logging.FileHandler('./LOG/personalityLog.log')
fileHandler.setFormatter(formatter)
logger.addHandler(streamHandler)
logger.addHandler(fileHandler)
USE_CUDA = torch.cuda.is_available()
# Out:
# /tmp/ipykernel_4038902/3498005901.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
logger.debug('============={}+Video Vision Transformer Strat!============='.format(model_name))
USE_CUDA = torch.cuda.is_available()
print(USE_CUDA)

device = torch.device('cuda:0' if USE_CUDA else 'cpu')
print('학습을 진행하는 기기:', device)
# Out:
# [2024-09-20 00:36:39,073]::3184030073::DEBUG::=============15framesfullshot+Video Vision Transformer Strat!=============
# True
# 학습을 진행하는 기기: cuda:0

# %%
def getdata(pathname,datatype):
    if datatype=="train":
        final_data_set=[]
        output_file=open(pathname, "rb")
        for i in range(1):
            final_data_set.extend(pickle.load(output_file))
        return final_data_set
    elif datatype=="valid":
        final_data_set=[]
        output_file=open(pathname, "rb")
        for i in range(1):
            final_data_set.extend(pickle.load(output_file))
        return final_data_set
print(1)
# Out:
# 1

# %%
save_model_file_path = './save_swintransformer_folder/{}_{}.{}'
print(1)
# Out:
# 1

# %%
# validation_set_data=getdata("/data/qx/secwayofKrData/15Frames/test_set.dat","valid")
# print(1)
validation_set_data=getdata("/data/qx/firstwayofKrData/15FramesDataset30s/test_set.dat","valid")
print(1)
# Out:
# 1

# %%
# train_set_data=getdata("/data/qx/secwayofKrData/15Frames/train_set.dat","train")
# print(1)
train_set_data=getdata("/data/qx/firstwayofKrData/15FramesDataset30s/train_set.dat","train")
print(1)
# Out:
# 1

# %%
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.ToTensor(),
])
print(1)
# Out:
# 1

# %%
class ChalearnDataset(Dataset):
    def __init__(self,fullshot,tagdata,transform=None):
        self.fullshot=fullshot
        self.tagdata=tagdata
        self.transform = transform  # 표준화 여부
    def __len__(self):
        return len(self.fullshot)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()#텐서의 경우 목록으로 돌아가기
        fullshot=self.fullshot[idx]
        fullshot=torch.FloatTensor(fullshot)
        big_five_sorces=self.tagdata[idx]
        big_five_sorces = torch.FloatTensor(big_five_sorces)
        return fullshot,big_five_sorces
print(1)
# Out:
# 1

# %%
num_workerssz = 20
lr = 3e-05
epochs = 120
print(1)
# Out:
# 1

# %%
train_set_data = ChalearnDataset(fullshot = train_set_data[1],tagdata=train_set_data[3],transform=transform)
val_set_data = ChalearnDataset(fullshot = validation_set_data[1],tagdata=validation_set_data[3],transform=transform)
train_dataloader = DataLoader(dataset=train_set_data, batch_size=batchsz, shuffle=True, num_workers=num_workerssz)
val_dataloader = DataLoader(dataset=val_set_data, batch_size=batchsz, shuffle=True, num_workers=num_workerssz)
max_value=0
print(1)
# Out:
# 1

# %%
model=ViViTBackbone(2, 14, 14, 2, 2, 2, 5, 96, 6, 10, 8, model=3)#num_frames=frame_nums,batchsz = batchsz
model=model.to(device)
criterion = torch.nn.L1Loss().to(device) # 손실함수
optimizer = torch.optim.AdamW(model.parameters(), lr=lr) # 옵티마이저

if test_flage==True:
    checkpoint=torch.load(save_model_file_path.format('model',start_epoch,'pth'), map_location=device)
    model.load_state_dict(checkpoint["model"])
    optimizer.load_state_dict(checkpoint["optimizer"])
    criterion.load_state_dict(checkpoint["loss"])
train_avg_loss0=[]
val_avg_loss0=[]
print(1)
# Out:
# 1

# %%
from torchinfo import summary

summary(model, input_size = ((4, 3,15, 224, 224)), col_names = ['input_size','output_size','num_params'],verbose = 1)
# Out:
# =============================================================================================================================
# Layer (type:depth-idx)                             Input Shape               Output Shape              Param #
# =============================================================================================================================
# ViViTBackbone                                      [4, 3, 15, 224, 224]      [4, 5]                    3,146,016
# ├─VideoResNet: 1-1                                 [4, 3, 15, 224, 224]      [4, 512, 2, 14, 14]       205,200
# │    └─R2Plus1dStem: 2-1                           [4, 3, 15, 224, 224]      [4, 64, 15, 112, 112]     --
# │    │    └─Conv3d: 3-1                            [4, 3, 15, 224, 224]      [4, 45, 15, 112, 112]     6,615
# │    │    └─BatchNorm3d: 3-2                       [4, 45, 15, 112, 112]     [4, 45, 15, 112, 112]     90
# │    │    └─ReLU: 3-3                              [4, 45, 15, 112, 112]     [4, 45, 15, 112, 112]     --
# │    │    └─Conv3d: 3-4                            [4, 45, 15, 112, 112]     [4, 64, 15, 112, 112]     8,640
# │    │    └─BatchNorm3d: 3-5                       [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     128
# │    │    └─ReLU: 3-6                              [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     --
# │    └─Sequential: 2-2                             [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     --
# │    │    └─BasicBlock: 3-7                        [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     222,016
# │    │    └─BasicBlock: 3-8                        [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     222,016
# │    └─Sequential: 2-3                             [4, 64, 15, 112, 112]     [4, 128, 8, 56, 56]       --
# │    │    └─BasicBlock: 3-9                        [4, 64, 15, 112, 112]     [4, 128, 8, 56, 56]       583,960
# │    │    └─BasicBlock: 3-10                       [4, 128, 8, 56, 56]       [4, 128, 8, 56, 56]       886,400
# │    └─Sequential: 2-4                             [4, 128, 8, 56, 56]       [4, 256, 4, 28, 28]       --
# │    │    └─BasicBlock: 3-11                       [4, 128, 8, 56, 56]       [4, 256, 4, 28, 28]       2,332,464
# │    │    └─BasicBlock: 3-12                       [4, 256, 4, 28, 28]       [4, 256, 4, 28, 28]       3,542,272
# │    └─Sequential: 2-5                             [4, 256, 4, 28, 28]       [4, 512, 2, 14, 14]       --
# │    │    └─BasicBlock: 3-13                       [4, 256, 4, 28, 28]       [4, 512, 2, 14, 14]       9,333,092
# │    │    └─BasicBlock: 3-14                       [4, 512, 2, 14, 14]       [4, 512, 2, 14, 14]       14,162,432
# ├─Sequential: 1-2                                  [4, 512, 2, 14, 14]       [4, 1, 49, 96]            --
# │    └─Rearrange: 2-6                              [4, 512, 2, 14, 14]       [4, 1, 49, 4096]          --
# │    └─Linear: 2-7                                 [4, 1, 49, 4096]          [4, 1, 49, 96]            393,312
# ├─Dropout: 1-3                                     [4, 1, 49, 96]            [4, 1, 49, 96]            --
# ├─FSATransformerEncoder: 1-4                       [4, 1, 49, 96]            [4, 49, 96]               --
# │    └─ModuleList: 2-8                             --                        --                        --
# │    │    └─ModuleList: 3-15                       --                        --                        25,448
# │    │    └─ModuleList: 3-16                       --                        --                        25,448
# │    │    └─ModuleList: 3-17                       --                        --                        25,448
# │    │    └─ModuleList: 3-18                       --                        --                        25,448
# │    │    └─ModuleList: 3-19                       --                        --                        25,448
# │    │    └─ModuleList: 3-20                       --                        --                        25,448
# ├─Identity: 1-5                                    [4, 96]                   [4, 96]                   --
# ├─Sequential: 1-6                                  [4, 96]                   [4, 5]                    --
# │    └─LayerNorm: 2-9                              [4, 96]                   [4, 96]                   192
# │    └─Linear: 2-10                                [4, 96]                   [4, 5]                    485
# =============================================================================================================================
# Total params: 35,198,018
# Trainable params: 35,198,018
# Non-trainable params: 0
# Total mult-adds (G): 623.70
# =============================================================================================================================
# Input size (MB): 36.13
# Forward/backward pass size (MB): 15309.69
# Params size (MB): 127.39
# Estimated Total Size (MB): 15473.21
# =============================================================================================================================
# =============================================================================================================================
# Layer (type:depth-idx)                             Input Shape               Output Shape              Param #
# =============================================================================================================================
# ViViTBackbone                                      [4, 3, 15, 224, 224]      [4, 5]                    3,146,016
# ├─VideoResNet: 1-1                                 [4, 3, 15, 224, 224]      [4, 512, 2, 14, 14]       205,200
# │    └─R2Plus1dStem: 2-1                           [4, 3, 15, 224, 224]      [4, 64, 15, 112, 112]     --
# │    │    └─Conv3d: 3-1                            [4, 3, 15, 224, 224]      [4, 45, 15, 112, 112]     6,615
# │    │    └─BatchNorm3d: 3-2                       [4, 45, 15, 112, 112]     [4, 45, 15, 112, 112]     90
# │    │    └─ReLU: 3-3                              [4, 45, 15, 112, 112]     [4, 45, 15, 112, 112]     --
# │    │    └─Conv3d: 3-4                            [4, 45, 15, 112, 112]     [4, 64, 15, 112, 112]     8,640
# │    │    └─BatchNorm3d: 3-5                       [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     128
# │    │    └─ReLU: 3-6                              [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     --
# │    └─Sequential: 2-2                             [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     --
# │    │    └─BasicBlock: 3-7                        [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     222,016
# │    │    └─BasicBlock: 3-8                        [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     222,016
# │    └─Sequential: 2-3                             [4, 64, 15, 112, 112]     [4, 128, 8, 56, 56]       --
# │    │    └─BasicBlock: 3-9                        [4, 64, 15, 112, 112]     [4, 128, 8, 56, 56]       583,960
# │    │    └─BasicBlock: 3-10                       [4, 128, 8, 56, 56]       [4, 128, 8, 56, 56]       886,400
# │    └─Sequential: 2-4                             [4, 128, 8, 56, 56]       [4, 256, 4, 28, 28]       --
# │    │    └─BasicBlock: 3-11                       [4, 128, 8, 56, 56]       [4, 256, 4, 28, 28]       2,332,464
# │    │    └─BasicBlock: 3-12                       [4, 256, 4, 28, 28]       [4, 256, 4, 28, 28]       3,542,272
# │    └─Sequential: 2-5                             [4, 256, 4, 28, 28]       [4, 512, 2, 14, 14]       --
# │    │    └─BasicBlock: 3-13                       [4, 256, 4, 28, 28]       [4, 512, 2, 14, 14]       9,333,092
# │    │    └─BasicBlock: 3-14                       [4, 512, 2, 14, 14]       [4, 512, 2, 14, 14]       14,162,432
# ├─Sequential: 1-2                                  [4, 512, 2, 14, 14]       [4, 1, 49, 96]            --
# │    └─Rearrange: 2-6                              [4, 512, 2, 14, 14]       [4, 1, 49, 4096]          --
# │    └─Linear: 2-7                                 [4, 1, 49, 4096]          [4, 1, 49, 96]            393,312
# ├─Dropout: 1-3                                     [4, 1, 49, 96]            [4, 1, 49, 96]            --
# ├─FSATransformerEncoder: 1-4                       [4, 1, 49, 96]            [4, 49, 96]               --
# │    └─ModuleList: 2-8                             --                        --                        --
# │    │    └─ModuleList: 3-15                       --                        --                        25,448
# │    │    └─ModuleList: 3-16                       --                        --                        25,448
# │    │    └─ModuleList: 3-17                       --                        --                        25,448
# │    │    └─ModuleList: 3-18                       --                        --                        25,448
# │    │    └─ModuleList: 3-19                       --                        --                        25,448
# │    │    └─ModuleList: 3-20                       --                        --                        25,448
# ├─Identity: 1-5                                    [4, 96]                   [4, 96]                   --
# ├─Sequential: 1-6                                  [4, 96]                   [4, 5]                    --
# │    └─LayerNorm: 2-9                              [4, 96]                   [4, 96]                   192
# │    └─Linear: 2-10                                [4, 96]                   [4, 5]                    485
# =============================================================================================================================
# Total params: 35,198,018
# Trainable params: 35,198,018
# Non-trainable params: 0
# Total mult-adds (G): 623.70
# =============================================================================================================================
# Input size (MB): 36.13
# Forward/backward pass size (MB): 15309.69
# Params size (MB): 127.39
# Estimated Total Size (MB): 15473.21
# =============================================================================================================================

# %%
def extract_ocean(data,batch_size):
    o=[]
    c=[]
    e=[]
    a=[]
    n=[]
    for i in range(batch_size):
        o.append(data[i][0].item())
        c.append(data[i][1].item())
        e.append(data[i][2].item())
        a.append(data[i][3].item())
        n.append(data[i][4].item())
    o = torch.tensor(o) 
    c = torch.tensor(c) 
    e = torch.tensor(e) 
    a = torch.tensor(a) 
    n = torch.tensor(n) 
    return o,c,e,a,n

# %%
max_value = float('inf')
for i in range(start_epoch, epochs):
    train_avg_loss = 0
    val_avg_loss = 0
    train_avg_o_loss = 0
    train_avg_c_loss = 0
    train_avg_e_loss = 0
    train_avg_a_loss = 0
    train_avg_n_loss = 0
    val_avg_o_loss = 0
    val_avg_c_loss = 0
    val_avg_e_loss = 0
    val_avg_a_loss = 0
    val_avg_n_loss = 0
    for fullshot,big_five_data in tqdm(train_dataloader):
        fullshot=fullshot.permute(0,4,1,2,3)
        big_five_data=big_five_data.permute(0,2,1)
        big_five_data=big_five_data.squeeze()
        fullshot = fullshot.to(device)
        big_five_data = big_five_data.to(device)
        optimizer.zero_grad()  # 기울기가 0이 됩니다.
        hypothesis = model(fullshot) # 모델의 예측 결과를 저장합니다.
        loss = criterion(hypothesis, big_five_data)  # 예측된 결과와 실제 태그 사이의 손실 값을 저장합니다.
        loss.backward()  # 역방향 전파입니다. 
        optimizer.step()  
        train_avg_loss += loss  
    train_avg_loss=train_avg_loss/len(train_dataloader)
    with torch.no_grad():#validate
        for fullshot,big_five_data in tqdm(val_dataloader):
            fullshot=fullshot.permute(0,4,1,2,3)
            big_five_data=big_five_data.permute(0,2,1)
            big_five_data=big_five_data.squeeze()
            fullshot = fullshot.to(device)
            big_five_data = big_five_data.to(device)
            hypothesis = model(fullshot)
            val_loss = criterion(hypothesis, big_five_data)
            hypothesiso,hypothesisc,hypothesise,hypothesisa,hypothesisn=extract_ocean(hypothesis,batchsz)
            big_five_datao,big_five_datac,big_five_datae,big_five_dataa,big_five_datan=extract_ocean(big_five_data,batchsz)
            val_o_loss = criterion(hypothesiso, big_five_datao) 
            val_c_loss = criterion(hypothesisc, big_five_datac) 
            val_e_loss = criterion(hypothesise, big_five_datae) 
            val_a_loss = criterion(hypothesisa, big_five_dataa) 
            val_n_loss = criterion(hypothesisn, big_five_datan)  
            val_avg_loss += val_loss
            val_avg_o_loss += val_o_loss
            val_avg_c_loss += val_c_loss
            val_avg_e_loss += val_e_loss
            val_avg_a_loss += val_a_loss
            val_avg_n_loss += val_n_loss
        val_avg_loss=val_avg_loss/len(val_dataloader)
        val_avg_o_loss=val_avg_o_loss/len(val_dataloader)
        val_avg_c_loss=val_avg_c_loss/len(val_dataloader)
        val_avg_e_loss=val_avg_e_loss/len(val_dataloader)
        val_avg_a_loss=val_avg_a_loss/len(val_dataloader)
        val_avg_n_loss=val_avg_n_loss/len(val_dataloader)
    torch.cuda.empty_cache()
    start_epoch+=1
    if val_avg_loss < max_value:
        max_value=val_avg_loss
        torch.save({
            'epoch': i+1,
            'model': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'loss': val_avg_loss,
        }, save_model_file_path.format('model',start_epoch,'pth'))
    logger.debug('Epoch: {} , 1-MAE: {:.4f} , 1-Training Loss: {:.4f} , 1-val_avg_o_loss:{:.4f} , 1-val_avg_c_loss:{:.4f} , 1-val_avg_e_loss:{:.4f} , 1-val_avg_a_loss:{:.4f} , 1-val_avg_n_loss:{:.4f}'.format(i+1, 1-val_avg_loss, 1-train_avg_loss,1-val_avg_o_loss, 1-val_avg_c_loss, 1-val_avg_e_loss, 1-val_avg_a_loss,1-val_avg_n_loss))
# Out:
#   0%|          | 0/1495 [00:00<?, ?it/s]
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.95it/s]
# [2024-09-20 00:43:23,410]::3746580590::DEBUG::Epoch: 1 , 1-MAE: 0.8592 , 1-Training Loss: 0.9465 , 1-val_avg_o_loss:0.8737 , 1-val_avg_c_loss:0.8700 , 1-val_avg_e_loss:0.8462 , 1-val_avg_a_loss:0.8708 , 1-val_avg_n_loss:0.8355
# 100%|██████████| 1495/1495 [05:46<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.96it/s]
# [2024-09-20 00:49:49,351]::3746580590::DEBUG::Epoch: 2 , 1-MAE: 0.8663 , 1-Training Loss: 0.9754 , 1-val_avg_o_loss:0.8699 , 1-val_avg_c_loss:0.8718 , 1-val_avg_e_loss:0.8560 , 1-val_avg_a_loss:0.8887 , 1-val_avg_n_loss:0.8453
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:38<00:00,  9.91it/s]
# [2024-09-20 00:56:16,445]::3746580590::DEBUG::Epoch: 3 , 1-MAE: 0.8591 , 1-Training Loss: 0.9810 , 1-val_avg_o_loss:0.8672 , 1-val_avg_c_loss:0.8661 , 1-val_avg_e_loss:0.8476 , 1-val_avg_a_loss:0.8839 , 1-val_avg_n_loss:0.8305
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:38<00:00,  9.90it/s]
# [2024-09-20 01:02:44,276]::3746580590::DEBUG::Epoch: 4 , 1-MAE: 0.8605 , 1-Training Loss: 0.9841 , 1-val_avg_o_loss:0.8685 , 1-val_avg_c_loss:0.8567 , 1-val_avg_e_loss:0.8463 , 1-val_avg_a_loss:0.8912 , 1-val_avg_n_loss:0.8398
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.93it/s]
# [2024-09-20 01:09:11,595]::3746580590::DEBUG::Epoch: 5 , 1-MAE: 0.8612 , 1-Training Loss: 0.9861 , 1-val_avg_o_loss:0.8657 , 1-val_avg_c_loss:0.8663 , 1-val_avg_e_loss:0.8483 , 1-val_avg_a_loss:0.8892 , 1-val_avg_n_loss:0.8364
# 100%|██████████| 1495/1495 [05:46<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.95it/s]
# [2024-09-20 01:15:37,314]::3746580590::DEBUG::Epoch: 6 , 1-MAE: 0.8611 , 1-Training Loss: 0.9878 , 1-val_avg_o_loss:0.8631 , 1-val_avg_c_loss:0.8676 , 1-val_avg_e_loss:0.8456 , 1-val_avg_a_loss:0.8934 , 1-val_avg_n_loss:0.8358
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 01:22:04,691]::3746580590::DEBUG::Epoch: 7 , 1-MAE: 0.8575 , 1-Training Loss: 0.9886 , 1-val_avg_o_loss:0.8624 , 1-val_avg_c_loss:0.8641 , 1-val_avg_e_loss:0.8462 , 1-val_avg_a_loss:0.8879 , 1-val_avg_n_loss:0.8267
# 100%|██████████| 1495/1495 [05:48<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.96it/s]
# [2024-09-20 01:28:31,513]::3746580590::DEBUG::Epoch: 8 , 1-MAE: 0.8576 , 1-Training Loss: 0.9895 , 1-val_avg_o_loss:0.8601 , 1-val_avg_c_loss:0.8612 , 1-val_avg_e_loss:0.8426 , 1-val_avg_a_loss:0.8879 , 1-val_avg_n_loss:0.8362
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.95it/s]
# [2024-09-20 01:34:58,046]::3746580590::DEBUG::Epoch: 9 , 1-MAE: 0.8586 , 1-Training Loss: 0.9901 , 1-val_avg_o_loss:0.8661 , 1-val_avg_c_loss:0.8609 , 1-val_avg_e_loss:0.8468 , 1-val_avg_a_loss:0.8867 , 1-val_avg_n_loss:0.8326
# 100%|██████████| 1495/1495 [05:45<00:00,  4.32it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 01:41:22,519]::3746580590::DEBUG::Epoch: 10 , 1-MAE: 0.8568 , 1-Training Loss: 0.9909 , 1-val_avg_o_loss:0.8624 , 1-val_avg_c_loss:0.8616 , 1-val_avg_e_loss:0.8436 , 1-val_avg_a_loss:0.8834 , 1-val_avg_n_loss:0.8330
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.95it/s]
# [2024-09-20 01:47:49,966]::3746580590::DEBUG::Epoch: 11 , 1-MAE: 0.8574 , 1-Training Loss: 0.9916 , 1-val_avg_o_loss:0.8661 , 1-val_avg_c_loss:0.8560 , 1-val_avg_e_loss:0.8464 , 1-val_avg_a_loss:0.8904 , 1-val_avg_n_loss:0.8283
# 100%|██████████| 1495/1495 [05:45<00:00,  4.32it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 01:54:14,769]::3746580590::DEBUG::Epoch: 12 , 1-MAE: 0.8553 , 1-Training Loss: 0.9919 , 1-val_avg_o_loss:0.8588 , 1-val_avg_c_loss:0.8623 , 1-val_avg_e_loss:0.8439 , 1-val_avg_a_loss:0.8868 , 1-val_avg_n_loss:0.8248
# 100%|██████████| 1495/1495 [05:46<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 02:00:40,185]::3746580590::DEBUG::Epoch: 13 , 1-MAE: 0.8565 , 1-Training Loss: 0.9923 , 1-val_avg_o_loss:0.8627 , 1-val_avg_c_loss:0.8604 , 1-val_avg_e_loss:0.8433 , 1-val_avg_a_loss:0.8871 , 1-val_avg_n_loss:0.8288
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.99it/s]
# [2024-09-20 02:07:06,216]::3746580590::DEBUG::Epoch: 14 , 1-MAE: 0.8548 , 1-Training Loss: 0.9928 , 1-val_avg_o_loss:0.8566 , 1-val_avg_c_loss:0.8550 , 1-val_avg_e_loss:0.8481 , 1-val_avg_a_loss:0.8865 , 1-val_avg_n_loss:0.8276
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.97it/s]
# [2024-09-20 02:13:33,311]::3746580590::DEBUG::Epoch: 15 , 1-MAE: 0.8531 , 1-Training Loss: 0.9931 , 1-val_avg_o_loss:0.8586 , 1-val_avg_c_loss:0.8531 , 1-val_avg_e_loss:0.8420 , 1-val_avg_a_loss:0.8864 , 1-val_avg_n_loss:0.8256
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.99it/s]
# [2024-09-20 02:20:00,378]::3746580590::DEBUG::Epoch: 16 , 1-MAE: 0.8541 , 1-Training Loss: 0.9935 , 1-val_avg_o_loss:0.8621 , 1-val_avg_c_loss:0.8580 , 1-val_avg_e_loss:0.8421 , 1-val_avg_a_loss:0.8851 , 1-val_avg_n_loss:0.8229
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.96it/s]
# [2024-09-20 02:26:27,880]::3746580590::DEBUG::Epoch: 17 , 1-MAE: 0.8525 , 1-Training Loss: 0.9936 , 1-val_avg_o_loss:0.8576 , 1-val_avg_c_loss:0.8569 , 1-val_avg_e_loss:0.8408 , 1-val_avg_a_loss:0.8842 , 1-val_avg_n_loss:0.8231
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 02:32:54,079]::3746580590::DEBUG::Epoch: 18 , 1-MAE: 0.8527 , 1-Training Loss: 0.9940 , 1-val_avg_o_loss:0.8561 , 1-val_avg_c_loss:0.8573 , 1-val_avg_e_loss:0.8398 , 1-val_avg_a_loss:0.8857 , 1-val_avg_n_loss:0.8245
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:38<00:00,  9.90it/s]
# [2024-09-20 02:39:20,338]::3746580590::DEBUG::Epoch: 19 , 1-MAE: 0.8539 , 1-Training Loss: 0.9941 , 1-val_avg_o_loss:0.8575 , 1-val_avg_c_loss:0.8582 , 1-val_avg_e_loss:0.8428 , 1-val_avg_a_loss:0.8850 , 1-val_avg_n_loss:0.8260
# 100%|██████████| 1495/1495 [05:46<00:00,  4.32it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.97it/s]
# [2024-09-20 02:45:45,492]::3746580590::DEBUG::Epoch: 20 , 1-MAE: 0.8535 , 1-Training Loss: 0.9941 , 1-val_avg_o_loss:0.8599 , 1-val_avg_c_loss:0.8559 , 1-val_avg_e_loss:0.8398 , 1-val_avg_a_loss:0.8869 , 1-val_avg_n_loss:0.8248
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.95it/s]
# [2024-09-20 02:52:11,655]::3746580590::DEBUG::Epoch: 21 , 1-MAE: 0.8525 , 1-Training Loss: 0.9946 , 1-val_avg_o_loss:0.8625 , 1-val_avg_c_loss:0.8492 , 1-val_avg_e_loss:0.8410 , 1-val_avg_a_loss:0.8803 , 1-val_avg_n_loss:0.8295
# 100%|██████████| 1495/1495 [05:47<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.96it/s]
# [2024-09-20 02:58:37,601]::3746580590::DEBUG::Epoch: 22 , 1-MAE: 0.8517 , 1-Training Loss: 0.9945 , 1-val_avg_o_loss:0.8587 , 1-val_avg_c_loss:0.8540 , 1-val_avg_e_loss:0.8381 , 1-val_avg_a_loss:0.8839 , 1-val_avg_n_loss:0.8236
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 03:05:04,055]::3746580590::DEBUG::Epoch: 23 , 1-MAE: 0.8524 , 1-Training Loss: 0.9947 , 1-val_avg_o_loss:0.8601 , 1-val_avg_c_loss:0.8522 , 1-val_avg_e_loss:0.8408 , 1-val_avg_a_loss:0.8842 , 1-val_avg_n_loss:0.8249
# 100%|██████████| 1495/1495 [05:47<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.95it/s]
# [2024-09-20 03:11:30,025]::3746580590::DEBUG::Epoch: 24 , 1-MAE: 0.8512 , 1-Training Loss: 0.9949 , 1-val_avg_o_loss:0.8566 , 1-val_avg_c_loss:0.8544 , 1-val_avg_e_loss:0.8366 , 1-val_avg_a_loss:0.8863 , 1-val_avg_n_loss:0.8223
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.93it/s]
# [2024-09-20 03:17:56,687]::3746580590::DEBUG::Epoch: 25 , 1-MAE: 0.8520 , 1-Training Loss: 0.9950 , 1-val_avg_o_loss:0.8570 , 1-val_avg_c_loss:0.8576 , 1-val_avg_e_loss:0.8379 , 1-val_avg_a_loss:0.8880 , 1-val_avg_n_loss:0.8192
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:38<00:00,  9.90it/s]
# [2024-09-20 03:24:22,968]::3746580590::DEBUG::Epoch: 26 , 1-MAE: 0.8527 , 1-Training Loss: 0.9949 , 1-val_avg_o_loss:0.8590 , 1-val_avg_c_loss:0.8537 , 1-val_avg_e_loss:0.8408 , 1-val_avg_a_loss:0.8875 , 1-val_avg_n_loss:0.8225
# 100%|██████████| 1495/1495 [05:49<00:00,  4.28it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.96it/s]
# [2024-09-20 03:30:50,932]::3746580590::DEBUG::Epoch: 27 , 1-MAE: 0.8521 , 1-Training Loss: 0.9953 , 1-val_avg_o_loss:0.8579 , 1-val_avg_c_loss:0.8531 , 1-val_avg_e_loss:0.8411 , 1-val_avg_a_loss:0.8844 , 1-val_avg_n_loss:0.8238
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.93it/s]
# [2024-09-20 03:37:18,100]::3746580590::DEBUG::Epoch: 28 , 1-MAE: 0.8516 , 1-Training Loss: 0.9954 , 1-val_avg_o_loss:0.8570 , 1-val_avg_c_loss:0.8548 , 1-val_avg_e_loss:0.8386 , 1-val_avg_a_loss:0.8864 , 1-val_avg_n_loss:0.8212
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.98it/s]
# [2024-09-20 03:43:44,539]::3746580590::DEBUG::Epoch: 29 , 1-MAE: 0.8533 , 1-Training Loss: 0.9953 , 1-val_avg_o_loss:0.8625 , 1-val_avg_c_loss:0.8512 , 1-val_avg_e_loss:0.8447 , 1-val_avg_a_loss:0.8817 , 1-val_avg_n_loss:0.8263
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.95it/s]
# [2024-09-20 03:50:11,889]::3746580590::DEBUG::Epoch: 30 , 1-MAE: 0.8503 , 1-Training Loss: 0.9955 , 1-val_avg_o_loss:0.8562 , 1-val_avg_c_loss:0.8524 , 1-val_avg_e_loss:0.8380 , 1-val_avg_a_loss:0.8840 , 1-val_avg_n_loss:0.8208
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 03:56:38,184]::3746580590::DEBUG::Epoch: 31 , 1-MAE: 0.8502 , 1-Training Loss: 0.9956 , 1-val_avg_o_loss:0.8545 , 1-val_avg_c_loss:0.8529 , 1-val_avg_e_loss:0.8380 , 1-val_avg_a_loss:0.8846 , 1-val_avg_n_loss:0.8209
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.96it/s]
# [2024-09-20 04:03:05,712]::3746580590::DEBUG::Epoch: 32 , 1-MAE: 0.8499 , 1-Training Loss: 0.9958 , 1-val_avg_o_loss:0.8571 , 1-val_avg_c_loss:0.8542 , 1-val_avg_e_loss:0.8373 , 1-val_avg_a_loss:0.8818 , 1-val_avg_n_loss:0.8190
# 100%|██████████| 1495/1495 [05:47<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:38<00:00,  9.91it/s]
# [2024-09-20 04:09:31,719]::3746580590::DEBUG::Epoch: 33 , 1-MAE: 0.8504 , 1-Training Loss: 0.9958 , 1-val_avg_o_loss:0.8571 , 1-val_avg_c_loss:0.8517 , 1-val_avg_e_loss:0.8380 , 1-val_avg_a_loss:0.8854 , 1-val_avg_n_loss:0.8201
# 100%|██████████| 1495/1495 [05:46<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.97it/s]
# [2024-09-20 04:15:57,027]::3746580590::DEBUG::Epoch: 34 , 1-MAE: 0.8514 , 1-Training Loss: 0.9958 , 1-val_avg_o_loss:0.8596 , 1-val_avg_c_loss:0.8536 , 1-val_avg_e_loss:0.8380 , 1-val_avg_a_loss:0.8840 , 1-val_avg_n_loss:0.8216
# 100%|██████████| 1495/1495 [05:49<00:00,  4.28it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.97it/s]
# [2024-09-20 04:22:24,735]::3746580590::DEBUG::Epoch: 35 , 1-MAE: 0.8526 , 1-Training Loss: 0.9959 , 1-val_avg_o_loss:0.8570 , 1-val_avg_c_loss:0.8541 , 1-val_avg_e_loss:0.8434 , 1-val_avg_a_loss:0.8864 , 1-val_avg_n_loss:0.8223
# 100%|██████████| 1495/1495 [05:48<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.95it/s]
# [2024-09-20 04:28:51,560]::3746580590::DEBUG::Epoch: 36 , 1-MAE: 0.8517 , 1-Training Loss: 0.9961 , 1-val_avg_o_loss:0.8588 , 1-val_avg_c_loss:0.8499 , 1-val_avg_e_loss:0.8410 , 1-val_avg_a_loss:0.8864 , 1-val_avg_n_loss:0.8225
# 100%|██████████| 1495/1495 [05:46<00:00,  4.32it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.95it/s]
# [2024-09-20 04:35:16,471]::3746580590::DEBUG::Epoch: 37 , 1-MAE: 0.8495 , 1-Training Loss: 0.9961 , 1-val_avg_o_loss:0.8568 , 1-val_avg_c_loss:0.8504 , 1-val_avg_e_loss:0.8369 , 1-val_avg_a_loss:0.8834 , 1-val_avg_n_loss:0.8201
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.97it/s]
# [2024-09-20 04:41:43,080]::3746580590::DEBUG::Epoch: 38 , 1-MAE: 0.8511 , 1-Training Loss: 0.9962 , 1-val_avg_o_loss:0.8548 , 1-val_avg_c_loss:0.8527 , 1-val_avg_e_loss:0.8389 , 1-val_avg_a_loss:0.8855 , 1-val_avg_n_loss:0.8237
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:38<00:00,  9.92it/s]
# [2024-09-20 04:48:09,931]::3746580590::DEBUG::Epoch: 39 , 1-MAE: 0.8515 , 1-Training Loss: 0.9963 , 1-val_avg_o_loss:0.8571 , 1-val_avg_c_loss:0.8547 , 1-val_avg_e_loss:0.8381 , 1-val_avg_a_loss:0.8856 , 1-val_avg_n_loss:0.8219
# 100%|██████████| 1495/1495 [05:48<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.93it/s]
# [2024-09-20 04:54:36,847]::3746580590::DEBUG::Epoch: 40 , 1-MAE: 0.8514 , 1-Training Loss: 0.9963 , 1-val_avg_o_loss:0.8560 , 1-val_avg_c_loss:0.8493 , 1-val_avg_e_loss:0.8417 , 1-val_avg_a_loss:0.8864 , 1-val_avg_n_loss:0.8236
# 100%|██████████| 1495/1495 [05:47<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.96it/s]
# [2024-09-20 05:01:02,606]::3746580590::DEBUG::Epoch: 41 , 1-MAE: 0.8479 , 1-Training Loss: 0.9963 , 1-val_avg_o_loss:0.8548 , 1-val_avg_c_loss:0.8525 , 1-val_avg_e_loss:0.8335 , 1-val_avg_a_loss:0.8835 , 1-val_avg_n_loss:0.8156
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 05:07:29,086]::3746580590::DEBUG::Epoch: 42 , 1-MAE: 0.8496 , 1-Training Loss: 0.9964 , 1-val_avg_o_loss:0.8557 , 1-val_avg_c_loss:0.8524 , 1-val_avg_e_loss:0.8353 , 1-val_avg_a_loss:0.8864 , 1-val_avg_n_loss:0.8182
# 100%|██████████| 1495/1495 [05:46<00:00,  4.32it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 05:13:54,352]::3746580590::DEBUG::Epoch: 43 , 1-MAE: 0.8492 , 1-Training Loss: 0.9965 , 1-val_avg_o_loss:0.8558 , 1-val_avg_c_loss:0.8548 , 1-val_avg_e_loss:0.8314 , 1-val_avg_a_loss:0.8847 , 1-val_avg_n_loss:0.8194
# 100%|██████████| 1495/1495 [05:45<00:00,  4.33it/s]
# 100%|██████████| 377/377 [00:38<00:00,  9.91it/s]
# [2024-09-20 05:20:18,851]::3746580590::DEBUG::Epoch: 44 , 1-MAE: 0.8508 , 1-Training Loss: 0.9965 , 1-val_avg_o_loss:0.8590 , 1-val_avg_c_loss:0.8438 , 1-val_avg_e_loss:0.8428 , 1-val_avg_a_loss:0.8832 , 1-val_avg_n_loss:0.8250
# 100%|██████████| 1495/1495 [05:47<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 05:26:44,765]::3746580590::DEBUG::Epoch: 45 , 1-MAE: 0.8478 , 1-Training Loss: 0.9965 , 1-val_avg_o_loss:0.8546 , 1-val_avg_c_loss:0.8507 , 1-val_avg_e_loss:0.8324 , 1-val_avg_a_loss:0.8848 , 1-val_avg_n_loss:0.8164
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:38<00:00,  9.90it/s]
# [2024-09-20 05:33:11,263]::3746580590::DEBUG::Epoch: 46 , 1-MAE: 0.8476 , 1-Training Loss: 0.9967 , 1-val_avg_o_loss:0.8545 , 1-val_avg_c_loss:0.8536 , 1-val_avg_e_loss:0.8332 , 1-val_avg_a_loss:0.8815 , 1-val_avg_n_loss:0.8153
# 100%|██████████| 1495/1495 [05:45<00:00,  4.32it/s]
# 100%|██████████| 377/377 [00:38<00:00,  9.92it/s]
# [2024-09-20 05:39:36,167]::3746580590::DEBUG::Epoch: 47 , 1-MAE: 0.8464 , 1-Training Loss: 0.9966 , 1-val_avg_o_loss:0.8535 , 1-val_avg_c_loss:0.8537 , 1-val_avg_e_loss:0.8301 , 1-val_avg_a_loss:0.8828 , 1-val_avg_n_loss:0.8119
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.97it/s]
# [2024-09-20 05:46:02,597]::3746580590::DEBUG::Epoch: 48 , 1-MAE: 0.8493 , 1-Training Loss: 0.9968 , 1-val_avg_o_loss:0.8548 , 1-val_avg_c_loss:0.8513 , 1-val_avg_e_loss:0.8349 , 1-val_avg_a_loss:0.8884 , 1-val_avg_n_loss:0.8174
# 100%|██████████| 1495/1495 [05:47<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.95it/s]
# [2024-09-20 05:52:28,538]::3746580590::DEBUG::Epoch: 49 , 1-MAE: 0.8486 , 1-Training Loss: 0.9968 , 1-val_avg_o_loss:0.8576 , 1-val_avg_c_loss:0.8515 , 1-val_avg_e_loss:0.8323 , 1-val_avg_a_loss:0.8847 , 1-val_avg_n_loss:0.8171
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.95it/s]
# [2024-09-20 05:58:54,858]::3746580590::DEBUG::Epoch: 50 , 1-MAE: 0.8472 , 1-Training Loss: 0.9969 , 1-val_avg_o_loss:0.8537 , 1-val_avg_c_loss:0.8514 , 1-val_avg_e_loss:0.8339 , 1-val_avg_a_loss:0.8827 , 1-val_avg_n_loss:0.8145
# 100%|██████████| 1495/1495 [05:46<00:00,  4.32it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.95it/s]
# [2024-09-20 06:05:19,731]::3746580590::DEBUG::Epoch: 51 , 1-MAE: 0.8493 , 1-Training Loss: 0.9969 , 1-val_avg_o_loss:0.8563 , 1-val_avg_c_loss:0.8496 , 1-val_avg_e_loss:0.8367 , 1-val_avg_a_loss:0.8825 , 1-val_avg_n_loss:0.8213
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 06:11:46,405]::3746580590::DEBUG::Epoch: 52 , 1-MAE: 0.8483 , 1-Training Loss: 0.9968 , 1-val_avg_o_loss:0.8550 , 1-val_avg_c_loss:0.8506 , 1-val_avg_e_loss:0.8338 , 1-val_avg_a_loss:0.8831 , 1-val_avg_n_loss:0.8186
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.96it/s]
# [2024-09-20 06:18:12,657]::3746580590::DEBUG::Epoch: 53 , 1-MAE: 0.8491 , 1-Training Loss: 0.9970 , 1-val_avg_o_loss:0.8539 , 1-val_avg_c_loss:0.8483 , 1-val_avg_e_loss:0.8380 , 1-val_avg_a_loss:0.8857 , 1-val_avg_n_loss:0.8198
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:38<00:00,  9.90it/s]
# [2024-09-20 06:24:40,335]::3746580590::DEBUG::Epoch: 54 , 1-MAE: 0.8477 , 1-Training Loss: 0.9970 , 1-val_avg_o_loss:0.8536 , 1-val_avg_c_loss:0.8498 , 1-val_avg_e_loss:0.8328 , 1-val_avg_a_loss:0.8847 , 1-val_avg_n_loss:0.8176
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.96it/s]
# [2024-09-20 06:31:07,951]::3746580590::DEBUG::Epoch: 55 , 1-MAE: 0.8471 , 1-Training Loss: 0.9969 , 1-val_avg_o_loss:0.8530 , 1-val_avg_c_loss:0.8496 , 1-val_avg_e_loss:0.8315 , 1-val_avg_a_loss:0.8854 , 1-val_avg_n_loss:0.8158
# 100%|██████████| 1495/1495 [05:48<00:00,  4.28it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.93it/s]
# [2024-09-20 06:37:35,807]::3746580590::DEBUG::Epoch: 56 , 1-MAE: 0.8489 , 1-Training Loss: 0.9970 , 1-val_avg_o_loss:0.8572 , 1-val_avg_c_loss:0.8487 , 1-val_avg_e_loss:0.8376 , 1-val_avg_a_loss:0.8848 , 1-val_avg_n_loss:0.8164
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 06:44:03,258]::3746580590::DEBUG::Epoch: 57 , 1-MAE: 0.8488 , 1-Training Loss: 0.9971 , 1-val_avg_o_loss:0.8581 , 1-val_avg_c_loss:0.8486 , 1-val_avg_e_loss:0.8337 , 1-val_avg_a_loss:0.8886 , 1-val_avg_n_loss:0.8150
# 100%|██████████| 1495/1495 [05:47<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.97it/s]
# [2024-09-20 06:50:29,133]::3746580590::DEBUG::Epoch: 58 , 1-MAE: 0.8481 , 1-Training Loss: 0.9971 , 1-val_avg_o_loss:0.8560 , 1-val_avg_c_loss:0.8499 , 1-val_avg_e_loss:0.8320 , 1-val_avg_a_loss:0.8879 , 1-val_avg_n_loss:0.8147
# 100%|██████████| 1495/1495 [05:47<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 06:56:54,957]::3746580590::DEBUG::Epoch: 59 , 1-MAE: 0.8482 , 1-Training Loss: 0.9972 , 1-val_avg_o_loss:0.8551 , 1-val_avg_c_loss:0.8491 , 1-val_avg_e_loss:0.8339 , 1-val_avg_a_loss:0.8863 , 1-val_avg_n_loss:0.8165
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:38<00:00,  9.91it/s]
# [2024-09-20 07:03:22,702]::3746580590::DEBUG::Epoch: 60 , 1-MAE: 0.8484 , 1-Training Loss: 0.9971 , 1-val_avg_o_loss:0.8568 , 1-val_avg_c_loss:0.8486 , 1-val_avg_e_loss:0.8351 , 1-val_avg_a_loss:0.8844 , 1-val_avg_n_loss:0.8168
# 100%|██████████| 1495/1495 [05:46<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.92it/s]
# [2024-09-20 07:09:48,459]::3746580590::DEBUG::Epoch: 61 , 1-MAE: 0.8487 , 1-Training Loss: 0.9972 , 1-val_avg_o_loss:0.8562 , 1-val_avg_c_loss:0.8498 , 1-val_avg_e_loss:0.8353 , 1-val_avg_a_loss:0.8870 , 1-val_avg_n_loss:0.8150
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.95it/s]
# [2024-09-20 07:16:14,972]::3746580590::DEBUG::Epoch: 62 , 1-MAE: 0.8497 , 1-Training Loss: 0.9972 , 1-val_avg_o_loss:0.8575 , 1-val_avg_c_loss:0.8458 , 1-val_avg_e_loss:0.8413 , 1-val_avg_a_loss:0.8848 , 1-val_avg_n_loss:0.8188
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.98it/s]
# [2024-09-20 07:22:41,107]::3746580590::DEBUG::Epoch: 63 , 1-MAE: 0.8489 , 1-Training Loss: 0.9973 , 1-val_avg_o_loss:0.8566 , 1-val_avg_c_loss:0.8470 , 1-val_avg_e_loss:0.8378 , 1-val_avg_a_loss:0.8850 , 1-val_avg_n_loss:0.8179
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:38<00:00,  9.91it/s]
# [2024-09-20 07:29:08,387]::3746580590::DEBUG::Epoch: 64 , 1-MAE: 0.8470 , 1-Training Loss: 0.9972 , 1-val_avg_o_loss:0.8537 , 1-val_avg_c_loss:0.8495 , 1-val_avg_e_loss:0.8313 , 1-val_avg_a_loss:0.8835 , 1-val_avg_n_loss:0.8168
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 07:35:35,074]::3746580590::DEBUG::Epoch: 65 , 1-MAE: 0.8475 , 1-Training Loss: 0.9974 , 1-val_avg_o_loss:0.8548 , 1-val_avg_c_loss:0.8511 , 1-val_avg_e_loss:0.8326 , 1-val_avg_a_loss:0.8849 , 1-val_avg_n_loss:0.8139
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 07:42:01,195]::3746580590::DEBUG::Epoch: 66 , 1-MAE: 0.8469 , 1-Training Loss: 0.9974 , 1-val_avg_o_loss:0.8528 , 1-val_avg_c_loss:0.8529 , 1-val_avg_e_loss:0.8316 , 1-val_avg_a_loss:0.8822 , 1-val_avg_n_loss:0.8151
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.96it/s]
# [2024-09-20 07:48:28,429]::3746580590::DEBUG::Epoch: 67 , 1-MAE: 0.8490 , 1-Training Loss: 0.9973 , 1-val_avg_o_loss:0.8558 , 1-val_avg_c_loss:0.8513 , 1-val_avg_e_loss:0.8347 , 1-val_avg_a_loss:0.8830 , 1-val_avg_n_loss:0.8201
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.97it/s]
# [2024-09-20 07:54:54,732]::3746580590::DEBUG::Epoch: 68 , 1-MAE: 0.8481 , 1-Training Loss: 0.9974 , 1-val_avg_o_loss:0.8577 , 1-val_avg_c_loss:0.8511 , 1-val_avg_e_loss:0.8339 , 1-val_avg_a_loss:0.8836 , 1-val_avg_n_loss:0.8141
# 100%|██████████| 1495/1495 [05:47<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.96it/s]
# [2024-09-20 08:01:20,478]::3746580590::DEBUG::Epoch: 69 , 1-MAE: 0.8479 , 1-Training Loss: 0.9974 , 1-val_avg_o_loss:0.8555 , 1-val_avg_c_loss:0.8506 , 1-val_avg_e_loss:0.8312 , 1-val_avg_a_loss:0.8865 , 1-val_avg_n_loss:0.8156
# 100%|██████████| 1495/1495 [05:47<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.93it/s]
# [2024-09-20 08:07:46,515]::3746580590::DEBUG::Epoch: 70 , 1-MAE: 0.8501 , 1-Training Loss: 0.9975 , 1-val_avg_o_loss:0.8540 , 1-val_avg_c_loss:0.8469 , 1-val_avg_e_loss:0.8409 , 1-val_avg_a_loss:0.8880 , 1-val_avg_n_loss:0.8208
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.93it/s]
# [2024-09-20 08:14:13,018]::3746580590::DEBUG::Epoch: 71 , 1-MAE: 0.8458 , 1-Training Loss: 0.9974 , 1-val_avg_o_loss:0.8546 , 1-val_avg_c_loss:0.8500 , 1-val_avg_e_loss:0.8283 , 1-val_avg_a_loss:0.8838 , 1-val_avg_n_loss:0.8125
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.96it/s]
# [2024-09-20 08:20:40,085]::3746580590::DEBUG::Epoch: 72 , 1-MAE: 0.8479 , 1-Training Loss: 0.9975 , 1-val_avg_o_loss:0.8554 , 1-val_avg_c_loss:0.8466 , 1-val_avg_e_loss:0.8325 , 1-val_avg_a_loss:0.8870 , 1-val_avg_n_loss:0.8181
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:38<00:00,  9.91it/s]
# [2024-09-20 08:27:06,313]::3746580590::DEBUG::Epoch: 73 , 1-MAE: 0.8467 , 1-Training Loss: 0.9975 , 1-val_avg_o_loss:0.8522 , 1-val_avg_c_loss:0.8502 , 1-val_avg_e_loss:0.8292 , 1-val_avg_a_loss:0.8859 , 1-val_avg_n_loss:0.8157
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 08:33:32,835]::3746580590::DEBUG::Epoch: 74 , 1-MAE: 0.8466 , 1-Training Loss: 0.9974 , 1-val_avg_o_loss:0.8526 , 1-val_avg_c_loss:0.8505 , 1-val_avg_e_loss:0.8300 , 1-val_avg_a_loss:0.8854 , 1-val_avg_n_loss:0.8146
# 100%|██████████| 1495/1495 [05:49<00:00,  4.28it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.93it/s]
# [2024-09-20 08:40:00,884]::3746580590::DEBUG::Epoch: 75 , 1-MAE: 0.8468 , 1-Training Loss: 0.9975 , 1-val_avg_o_loss:0.8534 , 1-val_avg_c_loss:0.8470 , 1-val_avg_e_loss:0.8306 , 1-val_avg_a_loss:0.8858 , 1-val_avg_n_loss:0.8172
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.97it/s]
# [2024-09-20 08:46:27,076]::3746580590::DEBUG::Epoch: 76 , 1-MAE: 0.8449 , 1-Training Loss: 0.9976 , 1-val_avg_o_loss:0.8532 , 1-val_avg_c_loss:0.8506 , 1-val_avg_e_loss:0.8273 , 1-val_avg_a_loss:0.8825 , 1-val_avg_n_loss:0.8108
# 100%|██████████| 1495/1495 [05:46<00:00,  4.32it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.93it/s]
# [2024-09-20 08:52:52,245]::3746580590::DEBUG::Epoch: 77 , 1-MAE: 0.8474 , 1-Training Loss: 0.9976 , 1-val_avg_o_loss:0.8533 , 1-val_avg_c_loss:0.8464 , 1-val_avg_e_loss:0.8351 , 1-val_avg_a_loss:0.8853 , 1-val_avg_n_loss:0.8168
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.97it/s]
# [2024-09-20 08:59:19,656]::3746580590::DEBUG::Epoch: 78 , 1-MAE: 0.8467 , 1-Training Loss: 0.9975 , 1-val_avg_o_loss:0.8539 , 1-val_avg_c_loss:0.8512 , 1-val_avg_e_loss:0.8307 , 1-val_avg_a_loss:0.8827 , 1-val_avg_n_loss:0.8148
# 100%|██████████| 1495/1495 [05:48<00:00,  4.28it/s]
# 100%|██████████| 377/377 [00:38<00:00,  9.91it/s]
# [2024-09-20 09:05:47,578]::3746580590::DEBUG::Epoch: 79 , 1-MAE: 0.8468 , 1-Training Loss: 0.9976 , 1-val_avg_o_loss:0.8543 , 1-val_avg_c_loss:0.8516 , 1-val_avg_e_loss:0.8290 , 1-val_avg_a_loss:0.8819 , 1-val_avg_n_loss:0.8170
# 100%|██████████| 1495/1495 [05:46<00:00,  4.32it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.97it/s]
# [2024-09-20 09:12:12,567]::3746580590::DEBUG::Epoch: 80 , 1-MAE: 0.8484 , 1-Training Loss: 0.9976 , 1-val_avg_o_loss:0.8559 , 1-val_avg_c_loss:0.8527 , 1-val_avg_e_loss:0.8336 , 1-val_avg_a_loss:0.8848 , 1-val_avg_n_loss:0.8152
# 100%|██████████| 1495/1495 [05:47<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.96it/s]
# [2024-09-20 09:18:38,522]::3746580590::DEBUG::Epoch: 81 , 1-MAE: 0.8481 , 1-Training Loss: 0.9976 , 1-val_avg_o_loss:0.8530 , 1-val_avg_c_loss:0.8495 , 1-val_avg_e_loss:0.8323 , 1-val_avg_a_loss:0.8887 , 1-val_avg_n_loss:0.8170
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 09:25:04,774]::3746580590::DEBUG::Epoch: 82 , 1-MAE: 0.8475 , 1-Training Loss: 0.9976 , 1-val_avg_o_loss:0.8545 , 1-val_avg_c_loss:0.8484 , 1-val_avg_e_loss:0.8354 , 1-val_avg_a_loss:0.8862 , 1-val_avg_n_loss:0.8129
# 100%|██████████| 1495/1495 [05:47<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.92it/s]
# [2024-09-20 09:31:30,860]::3746580590::DEBUG::Epoch: 83 , 1-MAE: 0.8461 , 1-Training Loss: 0.9977 , 1-val_avg_o_loss:0.8537 , 1-val_avg_c_loss:0.8494 , 1-val_avg_e_loss:0.8291 , 1-val_avg_a_loss:0.8839 , 1-val_avg_n_loss:0.8144
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.99it/s]
# [2024-09-20 09:37:57,898]::3746580590::DEBUG::Epoch: 84 , 1-MAE: 0.8476 , 1-Training Loss: 0.9977 , 1-val_avg_o_loss:0.8548 , 1-val_avg_c_loss:0.8490 , 1-val_avg_e_loss:0.8339 , 1-val_avg_a_loss:0.8840 , 1-val_avg_n_loss:0.8162
# 100%|██████████| 1495/1495 [05:49<00:00,  4.27it/s]
# 100%|██████████| 377/377 [00:38<00:00,  9.91it/s]
# [2024-09-20 09:44:26,569]::3746580590::DEBUG::Epoch: 85 , 1-MAE: 0.8482 , 1-Training Loss: 0.9978 , 1-val_avg_o_loss:0.8536 , 1-val_avg_c_loss:0.8543 , 1-val_avg_e_loss:0.8332 , 1-val_avg_a_loss:0.8848 , 1-val_avg_n_loss:0.8149
# 100%|██████████| 1495/1495 [05:46<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 09:50:52,277]::3746580590::DEBUG::Epoch: 86 , 1-MAE: 0.8487 , 1-Training Loss: 0.9977 , 1-val_avg_o_loss:0.8539 , 1-val_avg_c_loss:0.8471 , 1-val_avg_e_loss:0.8400 , 1-val_avg_a_loss:0.8842 , 1-val_avg_n_loss:0.8181
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.96it/s]
# [2024-09-20 09:57:18,321]::3746580590::DEBUG::Epoch: 87 , 1-MAE: 0.8490 , 1-Training Loss: 0.9978 , 1-val_avg_o_loss:0.8556 , 1-val_avg_c_loss:0.8489 , 1-val_avg_e_loss:0.8340 , 1-val_avg_a_loss:0.8864 , 1-val_avg_n_loss:0.8199
# 100%|██████████| 1495/1495 [05:50<00:00,  4.27it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 10:03:47,407]::3746580590::DEBUG::Epoch: 88 , 1-MAE: 0.8476 , 1-Training Loss: 0.9977 , 1-val_avg_o_loss:0.8543 , 1-val_avg_c_loss:0.8511 , 1-val_avg_e_loss:0.8325 , 1-val_avg_a_loss:0.8859 , 1-val_avg_n_loss:0.8142
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.96it/s]
# [2024-09-20 10:10:14,505]::3746580590::DEBUG::Epoch: 89 , 1-MAE: 0.8463 , 1-Training Loss: 0.9978 , 1-val_avg_o_loss:0.8522 , 1-val_avg_c_loss:0.8502 , 1-val_avg_e_loss:0.8314 , 1-val_avg_a_loss:0.8846 , 1-val_avg_n_loss:0.8132
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.92it/s]
# [2024-09-20 10:16:41,654]::3746580590::DEBUG::Epoch: 90 , 1-MAE: 0.8453 , 1-Training Loss: 0.9978 , 1-val_avg_o_loss:0.8512 , 1-val_avg_c_loss:0.8504 , 1-val_avg_e_loss:0.8283 , 1-val_avg_a_loss:0.8839 , 1-val_avg_n_loss:0.8128
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.93it/s]
# [2024-09-20 10:23:08,892]::3746580590::DEBUG::Epoch: 91 , 1-MAE: 0.8480 , 1-Training Loss: 0.9979 , 1-val_avg_o_loss:0.8524 , 1-val_avg_c_loss:0.8525 , 1-val_avg_e_loss:0.8322 , 1-val_avg_a_loss:0.8869 , 1-val_avg_n_loss:0.8159
# 100%|██████████| 1495/1495 [05:49<00:00,  4.28it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 10:29:37,444]::3746580590::DEBUG::Epoch: 92 , 1-MAE: 0.8459 , 1-Training Loss: 0.9978 , 1-val_avg_o_loss:0.8516 , 1-val_avg_c_loss:0.8489 , 1-val_avg_e_loss:0.8306 , 1-val_avg_a_loss:0.8844 , 1-val_avg_n_loss:0.8141
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.99it/s]
# [2024-09-20 10:36:04,383]::3746580590::DEBUG::Epoch: 93 , 1-MAE: 0.8461 , 1-Training Loss: 0.9978 , 1-val_avg_o_loss:0.8534 , 1-val_avg_c_loss:0.8501 , 1-val_avg_e_loss:0.8288 , 1-val_avg_a_loss:0.8849 , 1-val_avg_n_loss:0.8131
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.97it/s]
# [2024-09-20 10:42:30,695]::3746580590::DEBUG::Epoch: 94 , 1-MAE: 0.8454 , 1-Training Loss: 0.9979 , 1-val_avg_o_loss:0.8538 , 1-val_avg_c_loss:0.8527 , 1-val_avg_e_loss:0.8263 , 1-val_avg_a_loss:0.8815 , 1-val_avg_n_loss:0.8128
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 10:48:58,162]::3746580590::DEBUG::Epoch: 95 , 1-MAE: 0.8465 , 1-Training Loss: 0.9978 , 1-val_avg_o_loss:0.8513 , 1-val_avg_c_loss:0.8517 , 1-val_avg_e_loss:0.8284 , 1-val_avg_a_loss:0.8839 , 1-val_avg_n_loss:0.8172
# 100%|██████████| 1495/1495 [05:49<00:00,  4.28it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 10:55:26,373]::3746580590::DEBUG::Epoch: 96 , 1-MAE: 0.8463 , 1-Training Loss: 0.9979 , 1-val_avg_o_loss:0.8535 , 1-val_avg_c_loss:0.8510 , 1-val_avg_e_loss:0.8288 , 1-val_avg_a_loss:0.8832 , 1-val_avg_n_loss:0.8151
# 100%|██████████| 1495/1495 [05:50<00:00,  4.27it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.93it/s]
# [2024-09-20 11:01:55,315]::3746580590::DEBUG::Epoch: 97 , 1-MAE: 0.8470 , 1-Training Loss: 0.9979 , 1-val_avg_o_loss:0.8522 , 1-val_avg_c_loss:0.8530 , 1-val_avg_e_loss:0.8304 , 1-val_avg_a_loss:0.8829 , 1-val_avg_n_loss:0.8166
# 100%|██████████| 1495/1495 [05:46<00:00,  4.32it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.93it/s]
# [2024-09-20 11:08:20,331]::3746580590::DEBUG::Epoch: 98 , 1-MAE: 0.8460 , 1-Training Loss: 0.9979 , 1-val_avg_o_loss:0.8513 , 1-val_avg_c_loss:0.8543 , 1-val_avg_e_loss:0.8288 , 1-val_avg_a_loss:0.8835 , 1-val_avg_n_loss:0.8122
# 100%|██████████| 1495/1495 [05:46<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.95it/s]
# [2024-09-20 11:14:45,922]::3746580590::DEBUG::Epoch: 99 , 1-MAE: 0.8448 , 1-Training Loss: 0.9978 , 1-val_avg_o_loss:0.8536 , 1-val_avg_c_loss:0.8513 , 1-val_avg_e_loss:0.8235 , 1-val_avg_a_loss:0.8823 , 1-val_avg_n_loss:0.8132
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.95it/s]
# [2024-09-20 11:21:12,092]::3746580590::DEBUG::Epoch: 100 , 1-MAE: 0.8449 , 1-Training Loss: 0.9979 , 1-val_avg_o_loss:0.8526 , 1-val_avg_c_loss:0.8491 , 1-val_avg_e_loss:0.8254 , 1-val_avg_a_loss:0.8839 , 1-val_avg_n_loss:0.8134
# 100%|██████████| 1495/1495 [05:47<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.93it/s]
# [2024-09-20 11:27:38,092]::3746580590::DEBUG::Epoch: 101 , 1-MAE: 0.8436 , 1-Training Loss: 0.9980 , 1-val_avg_o_loss:0.8502 , 1-val_avg_c_loss:0.8522 , 1-val_avg_e_loss:0.8198 , 1-val_avg_a_loss:0.8832 , 1-val_avg_n_loss:0.8127
# 100%|██████████| 1495/1495 [05:46<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.95it/s]
# [2024-09-20 11:34:03,435]::3746580590::DEBUG::Epoch: 102 , 1-MAE: 0.8429 , 1-Training Loss: 0.9980 , 1-val_avg_o_loss:0.8505 , 1-val_avg_c_loss:0.8547 , 1-val_avg_e_loss:0.8202 , 1-val_avg_a_loss:0.8811 , 1-val_avg_n_loss:0.8078
# 100%|██████████| 1495/1495 [05:46<00:00,  4.32it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.93it/s]
# [2024-09-20 11:40:28,379]::3746580590::DEBUG::Epoch: 103 , 1-MAE: 0.8460 , 1-Training Loss: 0.9980 , 1-val_avg_o_loss:0.8534 , 1-val_avg_c_loss:0.8515 , 1-val_avg_e_loss:0.8267 , 1-val_avg_a_loss:0.8850 , 1-val_avg_n_loss:0.8133
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 11:46:56,050]::3746580590::DEBUG::Epoch: 104 , 1-MAE: 0.8466 , 1-Training Loss: 0.9980 , 1-val_avg_o_loss:0.8548 , 1-val_avg_c_loss:0.8520 , 1-val_avg_e_loss:0.8248 , 1-val_avg_a_loss:0.8851 , 1-val_avg_n_loss:0.8162
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 11:53:22,485]::3746580590::DEBUG::Epoch: 105 , 1-MAE: 0.8465 , 1-Training Loss: 0.9980 , 1-val_avg_o_loss:0.8572 , 1-val_avg_c_loss:0.8520 , 1-val_avg_e_loss:0.8248 , 1-val_avg_a_loss:0.8828 , 1-val_avg_n_loss:0.8156
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.96it/s]
# [2024-09-20 11:59:48,565]::3746580590::DEBUG::Epoch: 106 , 1-MAE: 0.8489 , 1-Training Loss: 0.9979 , 1-val_avg_o_loss:0.8590 , 1-val_avg_c_loss:0.8461 , 1-val_avg_e_loss:0.8353 , 1-val_avg_a_loss:0.8855 , 1-val_avg_n_loss:0.8185
# 100%|██████████| 1495/1495 [05:47<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 12:06:14,466]::3746580590::DEBUG::Epoch: 107 , 1-MAE: 0.8484 , 1-Training Loss: 0.9981 , 1-val_avg_o_loss:0.8594 , 1-val_avg_c_loss:0.8483 , 1-val_avg_e_loss:0.8308 , 1-val_avg_a_loss:0.8861 , 1-val_avg_n_loss:0.8176
# 100%|██████████| 1495/1495 [05:47<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.93it/s]
# [2024-09-20 12:12:40,375]::3746580590::DEBUG::Epoch: 108 , 1-MAE: 0.8459 , 1-Training Loss: 0.9980 , 1-val_avg_o_loss:0.8558 , 1-val_avg_c_loss:0.8487 , 1-val_avg_e_loss:0.8263 , 1-val_avg_a_loss:0.8860 , 1-val_avg_n_loss:0.8126
# 100%|██████████| 1495/1495 [05:45<00:00,  4.32it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 12:19:05,154]::3746580590::DEBUG::Epoch: 109 , 1-MAE: 0.8474 , 1-Training Loss: 0.9980 , 1-val_avg_o_loss:0.8576 , 1-val_avg_c_loss:0.8482 , 1-val_avg_e_loss:0.8279 , 1-val_avg_a_loss:0.8880 , 1-val_avg_n_loss:0.8154
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:38<00:00,  9.91it/s]
# [2024-09-20 12:25:31,807]::3746580590::DEBUG::Epoch: 110 , 1-MAE: 0.8476 , 1-Training Loss: 0.9980 , 1-val_avg_o_loss:0.8579 , 1-val_avg_c_loss:0.8479 , 1-val_avg_e_loss:0.8315 , 1-val_avg_a_loss:0.8847 , 1-val_avg_n_loss:0.8160
# 100%|██████████| 1495/1495 [05:46<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.98it/s]
# [2024-09-20 12:31:57,253]::3746580590::DEBUG::Epoch: 111 , 1-MAE: 0.8459 , 1-Training Loss: 0.9980 , 1-val_avg_o_loss:0.8531 , 1-val_avg_c_loss:0.8510 , 1-val_avg_e_loss:0.8256 , 1-val_avg_a_loss:0.8856 , 1-val_avg_n_loss:0.8144
# 100%|██████████| 1495/1495 [05:49<00:00,  4.27it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.93it/s]
# [2024-09-20 12:38:26,009]::3746580590::DEBUG::Epoch: 112 , 1-MAE: 0.8478 , 1-Training Loss: 0.9980 , 1-val_avg_o_loss:0.8601 , 1-val_avg_c_loss:0.8474 , 1-val_avg_e_loss:0.8325 , 1-val_avg_a_loss:0.8809 , 1-val_avg_n_loss:0.8183
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.94it/s]
# [2024-09-20 12:44:52,119]::3746580590::DEBUG::Epoch: 113 , 1-MAE: 0.8470 , 1-Training Loss: 0.9981 , 1-val_avg_o_loss:0.8577 , 1-val_avg_c_loss:0.8468 , 1-val_avg_e_loss:0.8296 , 1-val_avg_a_loss:0.8858 , 1-val_avg_n_loss:0.8154
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.92it/s]
# [2024-09-20 12:51:18,919]::3746580590::DEBUG::Epoch: 114 , 1-MAE: 0.8473 , 1-Training Loss: 0.9980 , 1-val_avg_o_loss:0.8610 , 1-val_avg_c_loss:0.8434 , 1-val_avg_e_loss:0.8310 , 1-val_avg_a_loss:0.8748 , 1-val_avg_n_loss:0.8262
# 100%|██████████| 1495/1495 [05:48<00:00,  4.29it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.93it/s]
# [2024-09-20 12:57:46,629]::3746580590::DEBUG::Epoch: 115 , 1-MAE: 0.8474 , 1-Training Loss: 0.9981 , 1-val_avg_o_loss:0.8611 , 1-val_avg_c_loss:0.8456 , 1-val_avg_e_loss:0.8324 , 1-val_avg_a_loss:0.8749 , 1-val_avg_n_loss:0.8232
# 100%|██████████| 1495/1495 [05:47<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.98it/s]
# [2024-09-20 13:04:12,298]::3746580590::DEBUG::Epoch: 116 , 1-MAE: 0.8476 , 1-Training Loss: 0.9981 , 1-val_avg_o_loss:0.8616 , 1-val_avg_c_loss:0.8471 , 1-val_avg_e_loss:0.8323 , 1-val_avg_a_loss:0.8730 , 1-val_avg_n_loss:0.8241
# 100%|██████████| 1495/1495 [05:46<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.98it/s]
# [2024-09-20 13:10:37,756]::3746580590::DEBUG::Epoch: 117 , 1-MAE: 0.8480 , 1-Training Loss: 0.9981 , 1-val_avg_o_loss:0.8618 , 1-val_avg_c_loss:0.8504 , 1-val_avg_e_loss:0.8308 , 1-val_avg_a_loss:0.8763 , 1-val_avg_n_loss:0.8207
# 100%|██████████| 1495/1495 [05:47<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:38<00:00,  9.91it/s]
# [2024-09-20 13:17:03,849]::3746580590::DEBUG::Epoch: 118 , 1-MAE: 0.8476 , 1-Training Loss: 0.9981 , 1-val_avg_o_loss:0.8598 , 1-val_avg_c_loss:0.8478 , 1-val_avg_e_loss:0.8292 , 1-val_avg_a_loss:0.8781 , 1-val_avg_n_loss:0.8231
# 100%|██████████| 1495/1495 [05:46<00:00,  4.31it/s]
# 100%|██████████| 377/377 [00:37<00:00,  9.93it/s]
# [2024-09-20 13:23:29,242]::3746580590::DEBUG::Epoch: 119 , 1-MAE: 0.8479 , 1-Training Loss: 0.9982 , 1-val_avg_o_loss:0.8583 , 1-val_avg_c_loss:0.8484 , 1-val_avg_e_loss:0.8335 , 1-val_avg_a_loss:0.8787 , 1-val_avg_n_loss:0.8203
# 100%|██████████| 1495/1495 [05:47<00:00,  4.30it/s]
# 100%|██████████| 377/377 [00:38<00:00,  9.92it/s]
# [2024-09-20 13:29:55,480]::3746580590::DEBUG::Epoch: 120 , 1-MAE: 0.8476 , 1-Training Loss: 0.9982 , 1-val_avg_o_loss:0.8592 , 1-val_avg_c_loss:0.8486 , 1-val_avg_e_loss:0.8318 , 1-val_avg_a_loss:0.8784 , 1-val_avg_n_loss:0.8199
